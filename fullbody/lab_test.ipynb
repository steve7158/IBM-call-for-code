# %%
import cv2
import matplotlib.pyplot as plt
import imutils
import matplotlib.image as mpimg
import camera_perspective
# Out:
# 36.24372049580271
# 24.61603163485585
# bottom:  7.646073966448598
# top:  182.97442353455332
# d_left:  9.488122307420044
# d_right:  44.4237635527154
# height_of_footprint: 34.93564124529536, width_of_footprint: 175.32834956810473

# %%
img=mpimg.imread('v')
print(img.shape)
orig=img
image = imutils.resize(img, width=min(400, img.shape[1]))
x=200
y=120
x_percent=x/image.shape[1]
y_percent=y/image.shape[0]
cv2.circle(img,(int(x_percent*img.shape[1]),int(y_percent*img.shape[0])),150,[255,0,0],-1)
plt.imshow(img)

image.shape
# Out:
# (3456, 5184, 3)
# (266, 400, 3)

# %%
a=[]
a.append(gener())

# %%
print(a)
# Out:
# [<generator object gener at 0x7fb0d458d258>]

# %%
video_capture=cv2.VideoCapture('videos/video.mp4')
while True:
    ret, frame=video_capture.read()
    
    plt.imshow(frame)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-dcaa88ec3d5b> in <module>
#       3     ret, frame=video_capture.read()
#       4
# ----> 5     plt.imshow(frame)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2697         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2698         resample=resample, url=url, **({"data": data} if data is not
# -> 2699         None else {}), **kwargs)
#    2700     sci(__ret)
#    2701     return __ret
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
# ...
